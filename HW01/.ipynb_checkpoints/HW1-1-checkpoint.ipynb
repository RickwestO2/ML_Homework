# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\gg750\anaconda3\lib\site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\gg750\anaconda3\lib\site-packages (from opencv-python) (1.24.3)

# %%
n=input("please enter number.\n")
while(1):
    if(n.isdigit()==True):
        if((int(n)>0 and int(n)<=20)):
            break
            
    print("ERROR,please enter number between 1~20.")
    n=input("please enter number.\n")


print("Number:",int(n))
# Out:
# please enter number.
# 6
# Number: 6

# %%
from PIL import Image
import matplotlib.pyplot as plt
import cv2
path="HW1 image/test/"
img = cv2.imread(path+"pic"+str(n)+".jpg")
# img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)# BGR -> RGB
plt.imshow(img) 
plt.axis('off')
print (img.shape)
# Out:
# (374, 500, 3)

# %%
new_img = cv2.resize(img, (64, 64), interpolation=cv2.INTER_AREA)
print (new_img.shape)
plt.imshow(new_img)
# Out:
# (64, 64, 3)

# %%
import pandas as pd
reference_path="HW1 image/reference/"
df = pd.DataFrame(columns=["Name", "value", "label"])
H=64
G=64
for m in range(1,51):
    #resize
    c_img = cv2.imread(reference_path+"cats/cat."+str(m)+".jpg")
    d_img = cv2.imread(reference_path+"dogs/dog."+str(m)+".jpg")
    c_img=cv2.resize(c_img, (64, 64), interpolation=cv2.INTER_AREA)
    d_img=cv2.resize(d_img, (64, 64), interpolation=cv2.INTER_AREA)
    
    c_value =0
    d_value =0
    for c in range(2):
        for i in range(H):
            for j in range(G):
                c_value+=(abs(int(c_img[i][j][c])-int(new_img[i][j][c]))/(64*64*3))
                d_value+=(abs(int(d_img[i][j][c])-int(new_img[i][j][c]))/(64*64*3))
    ctmp={'Name':"cat."+str(m),'value':c_value,'label':'cat'}
    dtmp={'Name':"dog."+str(m),'value':d_value,'label':'dog'}
#     print(ctmp)
#     print(dtmp)
    df = df.append(ctmp, ignore_index=True)
    df = df.append(dtmp, ignore_index=True)


df
# Out:
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_4152\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
#       Name      value label
# 0    cat.1  52.864258   cat
# 1    dog.1  42.358887   dog
# 2    cat.2  55.248861   cat
# 3    dog.2  43.545898   dog
# 4    cat.3  45.285075   cat
# ..     ...        ...   ...
# 95  dog.48  38.182861   dog
# 96  cat.49  52.873047   cat
# 97  dog.49  56.121745   dog
# 98  cat.50  47.238200   cat
# 99  dog.50  43.540527   dog
#
# [100 rows x 3 columns]

# %%
df=df.sort_values(by=['value'],ascending=True)
df=df.reset_index(drop=True)
df
# Out:
#       Name      value label
# 0   cat.30  34.917887   cat
# 1   dog.14  36.008057   dog
# 2   dog.17  37.832438   dog
# 3   dog.48  38.182861   dog
# 4   cat.16  38.869629   cat
# ..     ...        ...   ...
# 95  cat.18  64.596680   cat
# 96  dog.40  65.932210   dog
# 97  cat.37  66.727702   cat
# 98  dog.15  67.346680   dog
# 99  dog.19  74.899251   dog
#
# [100 rows x 3 columns]

# %%
k=3
dog=0
cat=0
for n in range(k):
    if(df['label'][n]=='cat'):
        print(df['Name'][n],":",df['value'][n])
        cat+=1
    else: #df2['label'][n]=='cat'
        print(df['Name'][n],":",df['value'][n])
        dog+=1
    t_img = cv2.imread(reference_path+str(df['label'][n])+"s/"+str(df['Name'][n])+".jpg")
    plt.imshow(t_img)
    plt.show()

print("\nResult: cat:{}, dog:{}".format(cat,dog))

if(cat>dog):
    print("Image is more like cat.")
else: #(dog>cat)
    print("Image is more like dog.")
# Out:
# cat.30 : 34.91788736979152
# dog.14 : 36.00805664062494
# dog.17 : 37.83243815104171
# Result: cat:1, dog:2
# Image is more like dog.

# %%
for k in range(1,50,2):
    dog=0
    cat=0
    for n in range(k):
        if(df['label'][n]=='cat'):
#             print(df['Name'][n],":",df['value'][n])
            cat+=1
        else: #df2['label'][n]=='cat'
#             print(df['Name'][n],":",df['value'][n])
            dog+=1
        t_img = cv2.imread(reference_path+str(df['label'][n])+"s/"+str(df['Name'][n])+".jpg")
#         plt.imshow(t_img)
#         plt.show()

    print("\nResult K:{}, cat:{}, dog:{}".format(k,cat,dog))

    if(cat>dog):
        print("Image is more like cat.")
    else: #(dog>cat)
        print("Image is more like dog.")
    print("\n.")
# Out:
# Result K:1, cat:1, dog:0
# Image is more like cat.
#
# .
#
# Result K:3, cat:1, dog:2
# Image is more like dog.
#
# .
#
# Result K:5, cat:2, dog:3
# Image is more like dog.
#
# .
#
# Result K:7, cat:3, dog:4
# Image is more like dog.
#
# .
#
# Result K:9, cat:4, dog:5
# Image is more like dog.
#
# .
#
# Result K:11, cat:5, dog:6
# Image is more like dog.
#
# .
#
# Result K:13, cat:6, dog:7
# Image is more like dog.
#
# .
#
# Result K:15, cat:7, dog:8
# Image is more like dog.
#
# .
#
# Result K:17, cat:7, dog:10
# Image is more like dog.
#
# .
#
# Result K:19, cat:7, dog:12
# Image is more like dog.
#
# .
#
# Result K:21, cat:7, dog:14
# Image is more like dog.
#
# .
#
# Result K:23, cat:8, dog:15
# Image is more like dog.
#
# .
#
# Result K:25, cat:10, dog:15
# Image is more like dog.
#
# .
#
# Result K:27, cat:11, dog:16
# Image is more like dog.
#
# .
#
# Result K:29, cat:11, dog:18
# Image is more like dog.
#
# .
#
# Result K:31, cat:13, dog:18
# Image is more like dog.
#
# .
#
# Result K:33, cat:13, dog:20
# Image is more like dog.
#
# .
#
# Result K:35, cat:14, dog:21
# Image is more like dog.
#
# .
#
# Result K:37, cat:15, dog:22
# Image is more like dog.
#
# .
#
# Result K:39, cat:17, dog:22
# Image is more like dog.
#
# .
#
# Result K:41, cat:17, dog:24
# Image is more like dog.
#
# .
#
# Result K:43, cat:19, dog:24
# Image is more like dog.
#
# .
#
# Result K:45, cat:19, dog:26
# Image is more like dog.
#
# .
#
# Result K:47, cat:21, dog:26
# Image is more like dog.
#
# .
#
# Result K:49, cat:21, dog:28
# Image is more like dog.
#
# .

# %% [markdown]
# 討論:
# 測試多個k值後，k=1時相對準確，但也不能算正確，因樣本數太過單一。
# 其他k值誤差更多，後續改善可能要更改算法或是再增加樣本數
