# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\gg750\anaconda3\lib\site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\gg750\anaconda3\lib\site-packages (from opencv-python) (1.24.3)

# %%
n=input("please enter number.\n")
while(1):
    if(n.isdigit()==True):
        if((int(n)>0 and int(n)<=20)):
            break
            
    print("ERROR,please enter number between 1~20.")
    n=input("please enter number.\n")


print("Number:",int(n))
# Out:
# please enter number.
# 11
# Number: 11

# %%
from PIL import Image
import matplotlib.pyplot as plt
import cv2
path="HW1 image/test/"
img = cv2.imread(path+"pic"+str(n)+".jpg")
# img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)# BGR -> RGB
plt.imshow(img) 
plt.axis('off')
print (img.shape)
# Out:
# (175, 225, 3)

# %%
new_img = cv2.resize(img, (64, 64), interpolation=cv2.INTER_AREA)
print (new_img.shape)
plt.imshow(new_img)
# Out:
# (64, 64, 3)

# %%
import pandas as pd
reference_path="HW1 image/reference/"
df = pd.DataFrame(columns=["Name", "value", "label"])
H=64
G=64
for m in range(1,51):
    #resize
    c_img = cv2.imread(reference_path+"cats/cat."+str(m)+".jpg")
    d_img = cv2.imread(reference_path+"dogs/dog."+str(m)+".jpg")
    c_img=cv2.resize(c_img, (64, 64), interpolation=cv2.INTER_AREA)
    d_img=cv2.resize(d_img, (64, 64), interpolation=cv2.INTER_AREA)
    
    c_value =0
    d_value =0
    for c in range(2):
        for i in range(H):
            for j in range(G):
                c_value+=(abs(int(c_img[i][j][c])-int(new_img[i][j][c]))/(64*64*3))
                d_value+=(abs(int(d_img[i][j][c])-int(new_img[i][j][c]))/(64*64*3))
    ctmp={'Name':"cat."+str(m),'value':c_value,'label':'cat'}
    dtmp={'Name':"dog."+str(m),'value':d_value,'label':'dog'}
#     print(ctmp)
#     print(dtmp)
    df = df.append(ctmp, ignore_index=True)
    df = df.append(dtmp, ignore_index=True)


df
# Out:
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ctmp, ignore_index=True)
# C:\Users\gg750\AppData\Local\Temp\ipykernel_1832\4065878443.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dtmp, ignore_index=True)
#       Name      value label
# 0    cat.1  46.682699   cat
# 1    dog.1  63.843018   dog
# 2    cat.2  54.671468   cat
# 3    dog.2  48.690837   dog
# 4    cat.3  54.760579   cat
# ..     ...        ...   ...
# 95  dog.48  39.477539   dog
# 96  cat.49  70.547770   cat
# 97  dog.49  56.454997   dog
# 98  cat.50  62.963379   cat
# 99  dog.50  46.851156   dog
#
# [100 rows x 3 columns]

# %%
df=df.sort_values(by=['value'],ascending=True)
df=df.reset_index(drop=True)
df
# Out:
#       Name      value label
# 0   cat.16  34.008708   cat
# 1    cat.4  36.340495   cat
# 2   dog.28  37.067383   dog
# 3   dog.42  38.971436   dog
# 4   cat.19  39.267578   cat
# ..     ...        ...   ...
# 95  cat.45  67.492594   cat
# 96  cat.49  70.547770   cat
# 97  cat.38  70.629720   cat
# 98   cat.5  73.535482   cat
# 99  cat.32  84.218343   cat
#
# [100 rows x 3 columns]

# %%
k=3
dog=0
cat=0
for t in range(k):
    if(df['label'][t]=='cat'):
        print(df['Name'][t],":",df['value'][t])
        cat+=1
    else: #df2['label'][t]=='cat'
        print(df['Name'][t],":",df['value'][t])
        dog+=1
    t_img = cv2.imread(reference_path+str(df['label'][t])+"s/"+str(df['Name'][t])+".jpg")
    plt.imshow(t_img)
    plt.show()

print("\nResult: cat:{}, dog:{}".format(cat,dog))

if(cat>dog):
    print("Image is more like cat.")
else: #(dog>cat)
    print("Image is more like dog.")
# Out:
# cat.16 : 34.008707682291785
# cat.4 : 36.34049479166667
# dog.28 : 37.06738281249989
# Result: cat:2, dog:1
# Image is more like cat.

# %%
for k in range(1,50,2):
    dog=0
    cat=0
    for t in range(k):
        if(df['label'][t]=='cat'):
#             print(df['Name'][t],":",df['value'][t])
            cat+=1
        else: #df2['label'][t]=='cat'
#             print(df['Name'][t],":",df['value'][t])
            dog+=1
        t_img = cv2.imread(reference_path+str(df['label'][t])+"s/"+str(df['Name'][t])+".jpg")
#         plt.imshow(t_img)
#         plt.show()

    print("\nResult K:{}, cat:{}, dog:{}".format(k,cat,dog))

    if(cat>dog):
        print("Image is more like cat.")
    else: #(dog>cat)
        print("Image is more like dog.")
    print("\n.")
# Out:
# Result K:1, cat:1, dog:0
# Image is more like cat.
#
# .
#
# Result K:3, cat:2, dog:1
# Image is more like cat.
#
# .
#
# Result K:5, cat:3, dog:2
# Image is more like cat.
#
# .
#
# Result K:7, cat:3, dog:4
# Image is more like dog.
#
# .
#
# Result K:9, cat:3, dog:6
# Image is more like dog.
#
# .
#
# Result K:11, cat:3, dog:8
# Image is more like dog.
#
# .
#
# Result K:13, cat:5, dog:8
# Image is more like dog.
#
# .
#
# Result K:15, cat:5, dog:10
# Image is more like dog.
#
# .
#
# Result K:17, cat:7, dog:10
# Image is more like dog.
#
# .
#
# Result K:19, cat:8, dog:11
# Image is more like dog.
#
# .
#
# Result K:21, cat:8, dog:13
# Image is more like dog.
#
# .
#
# Result K:23, cat:8, dog:15
# Image is more like dog.
#
# .
#
# Result K:25, cat:9, dog:16
# Image is more like dog.
#
# .
#
# Result K:27, cat:10, dog:17
# Image is more like dog.
#
# .
#
# Result K:29, cat:10, dog:19
# Image is more like dog.
#
# .
#
# Result K:31, cat:12, dog:19
# Image is more like dog.
#
# .
#
# Result K:33, cat:13, dog:20
# Image is more like dog.
#
# .
#
# Result K:35, cat:13, dog:22
# Image is more like dog.
#
# .
#
# Result K:37, cat:13, dog:24
# Image is more like dog.
#
# .
#
# Result K:39, cat:14, dog:25
# Image is more like dog.
#
# .
#
# Result K:41, cat:15, dog:26
# Image is more like dog.
#
# .
#
# Result K:43, cat:17, dog:26
# Image is more like dog.
#
# .
#
# Result K:45, cat:17, dog:28
# Image is more like dog.
#
# .
#
# Result K:47, cat:18, dog:29
# Image is more like dog.
#
# .
#
# Result K:49, cat:20, dog:29
# Image is more like dog.
#
# .

# %% [markdown]
# ## **嘗試不同 k 值對於判斷是貓狗的準確度的影響討論:**

# %% [markdown]
# ## **測試多個k值後，k=1時相對準確，但也不能採用。<br>因為資料集中，包含測試資料，當 k 為 1 時誤差為 0，<br>但當 k 為其它數值時，則是完全隨機的，誤差更多，<br>後續改善可能要更改算法或是再增加樣本數。**

# %% [markdown]
# ## **也請於 jupyter notebook 上面討論，此一判斷所選擇之圖片是貓還是狗的方式可能的問題:**

# %% [markdown]
# ## 若只用像素做比較，可能受到背景或其他物件所影響，顏色不能代表物體的種類，例如一個白色狗和白色的貓，在此種分類中可能會被當成同一種類，而白色貓和黑色的貓，可能會被當成不同種類。
